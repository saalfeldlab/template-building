# %% [markdown]
# Generate tables of statistics per-label for the supplement

# %%
import sys
import glob
import re
import fnmatch
import math
import datetime
import re
import os
from os import listdir
from os.path import join, isfile, basename

import itertools

import numpy as np
from numpy import float32, int32, uint8, dtype, genfromtxt

from scipy.stats import ttest_ind

import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, LogLocator, FormatStrFormatter
# %matplotlib inline

sys.path.append("../") # go to parent dir
import template_common as tc

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
# Global options
write_files_and_tables = True

# %%
dist_df, jac_df, hess_df, timeMem_df = tc.readStatTables()
grouped_label_table, total_table = tc.groupTables( dist_df, jac_df, hess_df, timeMem_df, tc.template_list  )
# Out:
# ../template_common.py:136: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['TEMPLATE'] = df.apply(lambda x: template_name(x['TEMPLATE']), axis=1)
# ../template_common.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['ALG'] = df.apply(lambda x: alg_name(x['ALG']), axis=1)
# ../template_common.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['TA'] = df.apply(lambda x: ''.join([x['TEMPLATE'],':',x['ALG']]), axis=1)

# %%
# dist_df.columns
# grouped_label_table.columns

# %%
# Filter out templates of interest

template_list = tc.template_list
print( template_list )

# filter templates
tmask = dist_df.apply( lambda x: (x['TEMPLATE'] in template_list ), axis=1)
df = dist_df.loc[tmask]

# Filter out appropriate rows and columns
dist_table = df.loc[ (df.ALG != 'ALL') & ((df.normalization == 'warp') | (df.normalization == 'na'))]
dist_table = tc.clean_names( dist_table )
# Out:
# ['JFRC2013_lo', 'JFRCtemplate2010', 'TeforBrain_f', 'F-antsFlip_lo', 'FCWB']
# ../template_common.py:136: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['TEMPLATE'] = df.apply(lambda x: template_name(x['TEMPLATE']), axis=1)
# ../template_common.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['ALG'] = df.apply(lambda x: alg_name(x['ALG']), axis=1)
# ../template_common.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['TA'] = df.apply(lambda x: ''.join([x['TEMPLATE'],':',x['ALG']]), axis=1)

# %%
template_order = ['JFRC2010','JFRC2013','JRC2018','FCWB','Tefor']
alg_order = ['ANTs A','ANTs B','ANTs C','CMTK A','CMTK B','CMTK C', 'Elastix A', 'Elastix B']
pd.options.display.float_format = '{:,.3f}'.format

row_order_tuples = [(x,y) for x,y in itertools.product( template_order, alg_order )]
df_writeme.loc[pd.MultiIndex.from_tuples( tuples )]

date_string = datetime.date.today().strftime('%Y%m%d')

for label in tc.labels:

    print( label )
    df_l = dist_table[ dist_table.LABEL == label ]
    df_writeme = df_l[['TEMPLATE','ALG','DISTANCE_mean','DISTANCE_std','DISTANCE_p10','DISTANCE_median','DISTANCE_p90','count']]
    df_writeme.columns = ['Template','Algorithm','Mean','Std dev','10th perc','median','90th perc','N']
    df_writeme = tc.toFloat( df_writeme, ['Mean','Std dev','10th perc','median','90th perc'] )
    df_writeme = df_writeme.set_index( ['Template','Algorithm'])
    
    # Re-order rows as desired
    df_writeme = df_writeme.loc[pd.MultiIndex.from_tuples( tuples )].reset_index()

    f = 'label_tables/label_clean2_%s_%s.tex' % ( label, date_string )

#     break
#     if( False ):
#     if( True ):
    if( write_files_and_tables ):

        print( f )
        with open( f, 'w') as tex_file:
            print( '\\begin{table}', file=tex_file )
            print( df_writeme.to_latex( multirow='True'), file=tex_file)
            print( '\caption{{ {} }}'.format( tc.get_label_string( label ).replace('_','\_')), file=tex_file )
            print( '\caption{{ {} }}'.format( tc.get_label_string( label ).replace('_','\_')) )
            print( '\end{table}', file=tex_file )
# Out:
# 16
# label_tables/label_clean2_16_20190911.tex
#    index JFRCtempate2010.mask130819     Name  Stack id           FBbt
# 0     14                      CRE_R  crepine        16  FBbt:00045037
#    index JFRCtempate2010.mask130819     Name  Stack id           FBbt
# 0     14                      CRE_R  crepine        16  FBbt:00045037
# \caption{ CRE\_R : crepine }
# 64
# ../template_common.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[ col ] = df.apply(lambda x: float(x[col]), axis=1)
# label_tables/label_clean2_64_20190911.tex
#    index JFRCtempate2010.mask130819                               Name  \
# 0     53                   MB_PED_L  pedunculus of adult mushroom body
#
#    Stack id           FBbt
# 0        64  FBbt:00007453
#    index JFRCtempate2010.mask130819                               Name  \
# 0     53                   MB_PED_L  pedunculus of adult mushroom body
#
#    Stack id           FBbt
# 0        64  FBbt:00007453
# \caption{ MB\_PED\_L : pedunculus of adult mushroom body }
# 8
# label_tables/label_clean2_8_20190911.tex
#    index JFRCtempate2010.mask130819                    Name  Stack id  \
# 0      6                      LAL_R  lateral accessory lobe         8
#
#             FBbt
# 0  FBbt:00003681
#    index JFRCtempate2010.mask130819                    Name  Stack id  \
# 0      6                      LAL_R  lateral accessory lobe         8
#
#             FBbt
# 0  FBbt:00003681
# \caption{ LAL\_R : lateral accessory lobe }
# 32
# label_tables/label_clean2_32_20190911.tex
#    index JFRCtempate2010.mask130819   Name  Stack id           FBbt
# 0     29                     IVLP_R  wedge        32  FBbt:00045027
#    index JFRCtempate2010.mask130819   Name  Stack id           FBbt
# 0     29                     IVLP_R  wedge        32  FBbt:00045027
# \caption{ IVLP\_R : wedge }
# 2
# label_tables/label_clean2_2_20190911.tex
#    index JFRCtempate2010.mask130819               Name  Stack id  \
# 0      0                      AME_R  accessory medulla         2
#
#             FBbt
# 0  FBbt:00045003
#    index JFRCtempate2010.mask130819               Name  Stack id  \
# 0      0                      AME_R  accessory medulla         2
#
#             FBbt
# 0  FBbt:00045003
# \caption{ AME\_R : accessory medulla }
# 4
# label_tables/label_clean2_4_20190911.tex
#    index JFRCtempate2010.mask130819     Name  Stack id           FBbt
# 0      2                         NO  nodulus         4  FBbt:00003680
#    index JFRCtempate2010.mask130819     Name  Stack id           FBbt
# 0      2                         NO  nodulus         4  FBbt:00003680
# \caption{ NO : nodulus }
# 65
# label_tables/label_clean2_65_20190911.tex
#    index JFRCtempate2010.mask130819                                  Name  \
# 0     54                    MB_VL_L  vertical lobe of adult mushroom body
#
#    Stack id           FBbt
# 0        65  FBbt:00015407
#    index JFRCtempate2010.mask130819                                  Name  \
# 0     54                    MB_VL_L  vertical lobe of adult mushroom body
#
#    Stack id           FBbt
# 0        65  FBbt:00015407
# \caption{ MB\_VL\_L : vertical lobe of adult mushroom body }
# 66
# label_tables/label_clean2_66_20190911.tex
#    index JFRCtempate2010.mask130819                                Name  \
# 0     55                    MB_ML_L  medial lobe of adult mushroom body
#
#    Stack id           FBbt
# 0        66  FBbt:00007677
#    index JFRCtempate2010.mask130819                                Name  \
# 0     55                    MB_ML_L  medial lobe of adult mushroom body
#
#    Stack id           FBbt
# 0        66  FBbt:00007677
# \caption{ MB\_ML\_L : medial lobe of adult mushroom body }
# 33
# label_tables/label_clean2_33_20190911.tex
#    index JFRCtempate2010.mask130819                             Name  \
# 0     30                      PLP_R  posterior lateral protocerebrum
#
#    Stack id           FBbt
# 0        33  FBbt:00040044
#    index JFRCtempate2010.mask130819                             Name  \
# 0     30                      PLP_R  posterior lateral protocerebrum
#
#    Stack id           FBbt
# 0        33  FBbt:00040044
# \caption{ PLP\_R : posterior lateral protocerebrum }
# 67
# label_tables/label_clean2_67_20190911.tex
#    index JFRCtempate2010.mask130819    Name  Stack id           FBbt
# 0     56                      FLA_L  flange        67  FBbt:00045050
#    index JFRCtempate2010.mask130819    Name  Stack id           FBbt
# 0     56                      FLA_L  flange        67  FBbt:00045050
# \caption{ FLA\_L : flange }
# 34
# label_tables/label_clean2_34_20190911.tex
#    index JFRCtempate2010.mask130819                     Name  Stack id  \
# 0     31                     AOTU_R  anterior optic tubercle        34
#
#             FBbt
# 0  FBbt:00007059
#    index JFRCtempate2010.mask130819                     Name  Stack id  \
# 0     31                     AOTU_R  anterior optic tubercle        34
#
#             FBbt
# 0  FBbt:00007059
# \caption{ AOTU\_R : anterior optic tubercle }
# 17
# label_tables/label_clean2_17_20190911.tex
#    index JFRCtempate2010.mask130819                               Name  \
# 0     15                   MB_PED_R  pedunculus of adult mushroom body
#
#    Stack id           FBbt
# 0        17  FBbt:00007453
#    index JFRCtempate2010.mask130819                               Name  \
# 0     15                   MB_PED_R  pedunculus of adult mushroom body
#
#    Stack id           FBbt
# 0        17  FBbt:00007453
# \caption{ MB\_PED\_R : pedunculus of adult mushroom body }
# 69
# label_tables/label_clean2_69_20190911.tex
#    index JFRCtempate2010.mask130819          Name  Stack id           FBbt
# 0     57                      LOP_L  lobula plate        69  FBbt:00003885
#    index JFRCtempate2010.mask130819          Name  Stack id           FBbt
# 0     57                      LOP_L  lobula plate        69  FBbt:00003885
# \caption{ LOP\_L : lobula plate }
# 70
# label_tables/label_clean2_70_20190911.tex
#    index JFRCtempate2010.mask130819                 Name  Stack id  \
# 0     58                       AL_L  adult antennal lobe        70
#
#             FBbt
# 0  FBbt:00007401
#    index JFRCtempate2010.mask130819                 Name  Stack id  \
# 0     58                       AL_L  adult antennal lobe        70
#
#             FBbt
# 0  FBbt:00007401
# \caption{ AL\_L : adult antennal lobe }
# 35
# label_tables/label_clean2_35_20190911.tex
#    index JFRCtempate2010.mask130819    Name  Stack id           FBbt
# 0     32                      GOR_R  gorget        35  FBbt:00040039
#    index JFRCtempate2010.mask130819    Name  Stack id           FBbt
# 0     32                      GOR_R  gorget        35  FBbt:00040039
# \caption{ GOR\_R : gorget }
# 71
# label_tables/label_clean2_71_20190911.tex
#    index JFRCtempate2010.mask130819     Name  Stack id           FBbt
# 0     59                       ME_L  medulla        71  FBbt:00003748
#    index JFRCtempate2010.mask130819     Name  Stack id           FBbt
# 0     59                       ME_L  medulla        71  FBbt:00003748
# \caption{ ME\_L : medulla }
# 9
# label_tables/label_clean2_9_20190911.tex
#    index JFRCtempate2010.mask130819    Name  Stack id           FBbt
# 0      7                        SAD  saddle         9  FBbt:00045048
#    index JFRCtempate2010.mask130819    Name  Stack id           FBbt
# 0      7                        SAD  saddle         9  FBbt:00045048
# \caption{ SAD : saddle }
# 18
# label_tables/label_clean2_18_20190911.tex
#    index JFRCtempate2010.mask130819                                  Name  \
# 0     16                    MB_VL_R  vertical lobe of adult mushroom body
#
#    Stack id           FBbt
# 0        18  FBbt:00015407
#    index JFRCtempate2010.mask130819                                  Name  \
# 0     16                    MB_VL_R  vertical lobe of adult mushroom body
#
#    Stack id           FBbt
# 0        18  FBbt:00015407
# \caption{ MB\_VL\_R : vertical lobe of adult mushroom body }
# 72
# label_tables/label_clean2_72_20190911.tex
#    index JFRCtempate2010.mask130819                            Name  Stack id  \
# 0     60                      SLP_L  superior lateral protocerebrum        72
#
#             FBbt
# 0  FBbt:00007054
#    index JFRCtempate2010.mask130819                            Name  Stack id  \
# 0     60                      SLP_L  superior lateral protocerebrum        72
#
#             FBbt
# 0  FBbt:00007054
# \caption{ SLP\_L : superior lateral protocerebrum }
# 36
# label_tables/label_clean2_36_20190911.tex
#    index JFRCtempate2010.mask130819                          Name  Stack id  \
# 0     33                    MB_CA_R  calyx of adult mushroom body        36
#
#             FBbt
# 0  FBbt:00007385
#    index JFRCtempate2010.mask130819                          Name  Stack id  \
# 0     33                    MB_CA_R  calyx of adult mushroom body        36
#
#             FBbt
# 0  FBbt:00007385
# \caption{ MB\_CA\_R : calyx of adult mushroom body }
# 73
# label_tables/label_clean2_73_20190911.tex
#    index JFRCtempate2010.mask130819                                 Name  \
# 0     61                      SIP_L  superior intermediate protocerebrum
#
#    Stack id           FBbt
# 0        73  FBbt:00045032
#    index JFRCtempate2010.mask130819                                 Name  \
# 0     61                      SIP_L  superior intermediate protocerebrum
#
#    Stack id           FBbt
# 0        73  FBbt:00045032
# \caption{ SIP\_L : superior intermediate protocerebrum }
# 74
# label_tables/label_clean2_74_20190911.tex
#    index JFRCtempate2010.mask130819                           Name  Stack id  \
# 0     62                      SMP_L  superior medial protocerebrum        74
#
#             FBbt
# 0  FBbt:00007055
#    index JFRCtempate2010.mask130819                           Name  Stack id  \
# 0     62                      SMP_L  superior medial protocerebrum        74
#
#             FBbt
# 0  FBbt:00007055
# \caption{ SMP\_L : superior medial protocerebrum }
# 37
# label_tables/label_clean2_37_20190911.tex
#    index JFRCtempate2010.mask130819                      Name  Stack id  \
# 0     34                      SPS_R  superior posterior slope        37
#
#             FBbt
# 0  FBbt:00045040
#    index JFRCtempate2010.mask130819                      Name  Stack id  \
# 0     34                      SPS_R  superior posterior slope        37
#
#             FBbt
# 0  FBbt:00045040
# \caption{ SPS\_R : superior posterior slope }
# 75
# label_tables/label_clean2_75_20190911.tex
#    index JFRCtempate2010.mask130819                                  Name  \
# 0     63                     AVLP_L  anterior ventrolateral protocerebrum
#
#    Stack id           FBbt
# 0        75  FBbt:00040043
#    index JFRCtempate2010.mask130819                                  Name  \
# 0     63                     AVLP_L  anterior ventrolateral protocerebrum
#
#    Stack id           FBbt
# 0        75  FBbt:00040043
# \caption{ AVLP\_L : anterior ventrolateral protocerebrum }
# 19
# label_tables/label_clean2_19_20190911.tex
#    index JFRCtempate2010.mask130819                                Name  \
# 0     17                    MB_ML_R  medial lobe of adult mushroom body
#
#    Stack id           FBbt
# 0        19  FBbt:00007677
#    index JFRCtempate2010.mask130819                                Name  \
# 0     17                    MB_ML_R  medial lobe of adult mushroom body
#
#    Stack id           FBbt
# 0        19  FBbt:00007677
# \caption{ MB\_ML\_R : medial lobe of adult mushroom body }
# 76
# label_tables/label_clean2_76_20190911.tex
#    index JFRCtempate2010.mask130819                                   Name  \
# 0     64                     PVLP_L  posterior ventrolateral protocerebrum
#
#    Stack id           FBbt
# 0        76  FBbt:00040042
#    index JFRCtempate2010.mask130819                                   Name  \
# 0     64                     PVLP_L  posterior ventrolateral protocerebrum
#
#    Stack id           FBbt
# 0        76  FBbt:00040042
# \caption{ PVLP\_L : posterior ventrolateral protocerebrum }
# 38
# label_tables/label_clean2_38_20190911.tex
#    index JFRCtempate2010.mask130819                      Name  Stack id  \
# 0     35                      IPS_R  inferior posterior slope        38
#
#             FBbt
# 0  FBbt:00045046
#    index JFRCtempate2010.mask130819                      Name  Stack id  \
# 0     35                      IPS_R  inferior posterior slope        38
#
#             FBbt
# 0  FBbt:00045046
# \caption{ IPS\_R : inferior posterior slope }
# 77
# label_tables/label_clean2_77_20190911.tex
#    index JFRCtempate2010.mask130819   Name  Stack id           FBbt
# 0     65                     IVLP_L  wedge        77  FBbt:00045027
#    index JFRCtempate2010.mask130819   Name  Stack id           FBbt
# 0     65                     IVLP_L  wedge        77  FBbt:00045027
# \caption{ IVLP\_L : wedge }
# 39
# label_tables/label_clean2_39_20190911.tex
#    index JFRCtempate2010.mask130819            Name  Stack id           FBbt
# 0     36                      SCL_R  superior clamp        39  FBbt:00040048
#    index JFRCtempate2010.mask130819            Name  Stack id           FBbt
# 0     36                      SCL_R  superior clamp        39  FBbt:00040048
# \caption{ SCL\_R : superior clamp }
# 78
# label_tables/label_clean2_78_20190911.tex
#    index JFRCtempate2010.mask130819                             Name  \
# 0     66                      PLP_L  posterior lateral protocerebrum
#
#    Stack id           FBbt
# 0        78  FBbt:00040044
#    index JFRCtempate2010.mask130819                             Name  \
# 0     66                      PLP_L  posterior lateral protocerebrum
#
#    Stack id           FBbt
# 0        78  FBbt:00040044
# \caption{ PLP\_L : posterior lateral protocerebrum }
# 79
# label_tables/label_clean2_79_20190911.tex
#    index JFRCtempate2010.mask130819                     Name  Stack id  \
# 0     67                     AOTU_L  anterior optic tubercle        79
#
#             FBbt
# 0  FBbt:00007059
#    index JFRCtempate2010.mask130819                     Name  Stack id  \
# 0     67                     AOTU_L  anterior optic tubercle        79
#
#             FBbt
# 0  FBbt:00007059
# \caption{ AOTU\_L : anterior optic tubercle }
# 20
# label_tables/label_clean2_20_20190911.tex
#    index JFRCtempate2010.mask130819    Name  Stack id           FBbt
# 0     18                      FLA_R  flange        20  FBbt:00045050
#    index JFRCtempate2010.mask130819    Name  Stack id           FBbt
# 0     18                      FLA_R  flange        20  FBbt:00045050
# \caption{ FLA\_R : flange }
# 5
# label_tables/label_clean2_5_20190911.tex
#    index JFRCtempate2010.mask130819  Name  Stack id           FBbt
# 0      3                       BU_R  bulb         5  FBbt:00003682
#    index JFRCtempate2010.mask130819  Name  Stack id           FBbt
# 0      3                       BU_R  bulb         5  FBbt:00003682
# \caption{ BU\_R : bulb }
# 40
# label_tables/label_clean2_40_20190911.tex
#    index JFRCtempate2010.mask130819       Name  Stack id           FBbt
# 0     37                      EPA_R  epaulette        40  FBbt:00040040
#    index JFRCtempate2010.mask130819       Name  Stack id           FBbt
# 0     37                      EPA_R  epaulette        40  FBbt:00040040
# \caption{ EPA\_R : epaulette }
# 80
# label_tables/label_clean2_80_20190911.tex
#    index JFRCtempate2010.mask130819    Name  Stack id           FBbt
# 0     68                      GOR_L  gorget        80  FBbt:00040039
#    index JFRCtempate2010.mask130819    Name  Stack id           FBbt
# 0     68                      GOR_L  gorget        80  FBbt:00040039
# \caption{ GOR\_L : gorget }
# 10
# label_tables/label_clean2_10_20190911.tex
#    index JFRCtempate2010.mask130819    Name  Stack id           FBbt
# 0      8                      CAN_R  cantle        10  FBbt:00045051
#    index JFRCtempate2010.mask130819    Name  Stack id           FBbt
# 0      8                      CAN_R  cantle        10  FBbt:00045051
# \caption{ CAN\_R : cantle }
# 81
# label_tables/label_clean2_81_20190911.tex
#    index JFRCtempate2010.mask130819                          Name  Stack id  \
# 0     69                    MB_CA_L  calyx of adult mushroom body        81
#
#             FBbt
# 0  FBbt:00007385
#    index JFRCtempate2010.mask130819                          Name  Stack id  \
# 0     69                    MB_CA_L  calyx of adult mushroom body        81
#
#             FBbt
# 0  FBbt:00007385
# \caption{ MB\_CA\_L : calyx of adult mushroom body }
# 82
# label_tables/label_clean2_82_20190911.tex
#    index JFRCtempate2010.mask130819                      Name  Stack id  \
# 0     70                      SPS_L  superior posterior slope        82
#
#             FBbt
# 0  FBbt:00045040
#    index JFRCtempate2010.mask130819                      Name  Stack id  \
# 0     70                      SPS_L  superior posterior slope        82
#
#             FBbt
# 0  FBbt:00045040
# \caption{ SPS\_L : superior posterior slope }
# 83
# label_tables/label_clean2_83_20190911.tex
#    index JFRCtempate2010.mask130819                      Name  Stack id  \
# 0     71                      IPS_L  inferior posterior slope        83
#
#             FBbt
# 0  FBbt:00045046
#    index JFRCtempate2010.mask130819                      Name  Stack id  \
# 0     71                      IPS_L  inferior posterior slope        83
#
#             FBbt
# 0  FBbt:00045046
# \caption{ IPS\_L : inferior posterior slope }
# 84
# label_tables/label_clean2_84_20190911.tex
#    index JFRCtempate2010.mask130819            Name  Stack id           FBbt
# 0     72                      SCL_L  superior clamp        84  FBbt:00040048
#    index JFRCtempate2010.mask130819            Name  Stack id           FBbt
# 0     72                      SCL_L  superior clamp        84  FBbt:00040048
# \caption{ SCL\_L : superior clamp }
# 85
# label_tables/label_clean2_85_20190911.tex
#    index JFRCtempate2010.mask130819       Name  Stack id           FBbt
# 0     73                      EPA_L  epaulette        85  FBbt:00040040
#    index JFRCtempate2010.mask130819       Name  Stack id           FBbt
# 0     73                      EPA_L  epaulette        85  FBbt:00040040
# \caption{ EPA\_L : epaulette }
# 86
# label_tables/label_clean2_86_20190911.tex
#    index JFRCtempate2010.mask130819  Name  Stack id           FBbt
# 0     74                       GA_L  gall        86  FBbt:00040060
#    index JFRCtempate2010.mask130819  Name  Stack id           FBbt
# 0     74                       GA_L  gall        86  FBbt:00040060
# \caption{ GA\_L : gall }
# 11
# label_tables/label_clean2_11_20190911.tex
#    index JFRCtempate2010.mask130819                                      Name  \
# 0      9                     AMMC_R  antennal mechanosensory and motor center
#
#    Stack id           FBbt
# 0        11  FBbt:00003982
#    index JFRCtempate2010.mask130819                                      Name  \
# 0      9                     AMMC_R  antennal mechanosensory and motor center
#
#    Stack id           FBbt
# 0        11  FBbt:00003982
# \caption{ AMMC\_R : antennal mechanosensory and motor center }
# 22
# label_tables/label_clean2_22_20190911.tex
#    index JFRCtempate2010.mask130819          Name  Stack id           FBbt
# 0     19                      LOP_R  lobula plate        22  FBbt:00003885
#    index JFRCtempate2010.mask130819          Name  Stack id           FBbt
# 0     19                      LOP_R  lobula plate        22  FBbt:00003885
# \caption{ LOP\_R : lobula plate }
# 23
# label_tables/label_clean2_23_20190911.tex
#    index JFRCtempate2010.mask130819            Name  Stack id           FBbt
# 0     20                         EB  ellipsoid body        23  FBbt:00003678
#    index JFRCtempate2010.mask130819            Name  Stack id           FBbt
# 0     20                         EB  ellipsoid body        23  FBbt:00003678
# \caption{ EB : ellipsoid body }
# 24
# label_tables/label_clean2_24_20190911.tex
#    index JFRCtempate2010.mask130819                 Name  Stack id  \
# 0     21                       AL_R  adult antennal lobe        24
#
#             FBbt
# 0  FBbt:00007401
#    index JFRCtempate2010.mask130819                 Name  Stack id  \
# 0     21                       AL_R  adult antennal lobe        24
#
#             FBbt
# 0  FBbt:00007401
# \caption{ AL\_R : adult antennal lobe }
# 12
# label_tables/label_clean2_12_20190911.tex
#    index JFRCtempate2010.mask130819            Name  Stack id           FBbt
# 0     10                      ICL_R  inferior clamp        12  FBbt:00040049
#    index JFRCtempate2010.mask130819            Name  Stack id           FBbt
# 0     10                      ICL_R  inferior clamp        12  FBbt:00040049
# \caption{ ICL\_R : inferior clamp }
# 3
# label_tables/label_clean2_3_20190911.tex
#    index JFRCtempate2010.mask130819    Name  Stack id           FBbt
# 0      1                       LO_R  lobula         3  FBbt:00003852
#    index JFRCtempate2010.mask130819    Name  Stack id           FBbt
# 0      1                       LO_R  lobula         3  FBbt:00003852
# \caption{ LO\_R : lobula }
# 6
# label_tables/label_clean2_6_20190911.tex
#    index JFRCtempate2010.mask130819                  Name  Stack id  \
# 0      4                         PB  protocerebral bridge         6
#
#             FBbt
# 0  FBbt:00003668
#    index JFRCtempate2010.mask130819                  Name  Stack id  \
# 0      4                         PB  protocerebral bridge         6
#
#             FBbt
# 0  FBbt:00003668
# \caption{ PB : protocerebral bridge }
# 49
# label_tables/label_clean2_49_20190911.tex
#    index JFRCtempate2010.mask130819                    Name  Stack id  \
# 0     38                        GNG  adult gnathal ganglion        49
#
#             FBbt
# 0  FBbt:00014013
#    index JFRCtempate2010.mask130819                    Name  Stack id  \
# 0     38                        GNG  adult gnathal ganglion        49
#
#             FBbt
# 0  FBbt:00014013
# \caption{ GNG : adult gnathal ganglion }
# 50
# label_tables/label_clean2_50_20190911.tex
#    index JFRCtempate2010.mask130819  Name  Stack id           FBbt
# 0     39                        PRW  prow        50  FBbt:00040051
#    index JFRCtempate2010.mask130819  Name  Stack id           FBbt
# 0     39                        PRW  prow        50  FBbt:00040051
# \caption{ PRW : prow }
# 25
# label_tables/label_clean2_25_20190911.tex
#    index JFRCtempate2010.mask130819     Name  Stack id           FBbt
# 0     22                       ME_R  medulla        25  FBbt:00003748
#    index JFRCtempate2010.mask130819     Name  Stack id           FBbt
# 0     22                       ME_R  medulla        25  FBbt:00003748
# \caption{ ME\_R : medulla }
# 51
# label_tables/label_clean2_51_20190911.tex
#    index JFRCtempate2010.mask130819  Name  Stack id           FBbt
# 0     40                       GA_R  gall        51  FBbt:00040060
#    index JFRCtempate2010.mask130819  Name  Stack id           FBbt
# 0     40                       GA_R  gall        51  FBbt:00040060
# \caption{ GA\_R : gall }
# 13
# label_tables/label_clean2_13_20190911.tex
#    index JFRCtempate2010.mask130819  Name  Stack id           FBbt
# 0     11                      VES_R  vest        13  FBbt:00040041
#    index JFRCtempate2010.mask130819  Name  Stack id           FBbt
# 0     11                      VES_R  vest        13  FBbt:00040041
# \caption{ VES\_R : vest }
# 52
# label_tables/label_clean2_52_20190911.tex
#    index JFRCtempate2010.mask130819               Name  Stack id  \
# 0     41                      AME_L  accessory medulla        52
#
#             FBbt
# 0  FBbt:00045003
#    index JFRCtempate2010.mask130819               Name  Stack id  \
# 0     41                      AME_L  accessory medulla        52
#
#             FBbt
# 0  FBbt:00045003
# \caption{ AME\_L : accessory medulla }
# 26
# label_tables/label_clean2_26_20190911.tex
#    index JFRCtempate2010.mask130819             Name  Stack id           FBbt
# 0     23                         FB  fan-shaped body        26  FBbt:00003679
#    index JFRCtempate2010.mask130819             Name  Stack id           FBbt
# 0     23                         FB  fan-shaped body        26  FBbt:00003679
# \caption{ FB : fan-shaped body }
# 53
# label_tables/label_clean2_53_20190911.tex
#    index JFRCtempate2010.mask130819    Name  Stack id           FBbt
# 0     42                       LO_L  lobula        53  FBbt:00003852
#    index JFRCtempate2010.mask130819    Name  Stack id           FBbt
# 0     42                       LO_L  lobula        53  FBbt:00003852
# \caption{ LO\_L : lobula }
# 27
# label_tables/label_clean2_27_20190911.tex
#    index JFRCtempate2010.mask130819                            Name  Stack id  \
# 0     24                      SLP_R  superior lateral protocerebrum        27
#
#             FBbt
# 0  FBbt:00007054
#    index JFRCtempate2010.mask130819                            Name  Stack id  \
# 0     24                      SLP_R  superior lateral protocerebrum        27
#
#             FBbt
# 0  FBbt:00007054
# \caption{ SLP\_R : superior lateral protocerebrum }
# 54
# label_tables/label_clean2_54_20190911.tex
#    index JFRCtempate2010.mask130819  Name  Stack id           FBbt
# 0     43                       BU_L  bulb        54  FBbt:00003682
#    index JFRCtempate2010.mask130819  Name  Stack id           FBbt
# 0     43                       BU_L  bulb        54  FBbt:00003682
# \caption{ BU\_L : bulb }
# 55
# label_tables/label_clean2_55_20190911.tex
#    index JFRCtempate2010.mask130819          Name  Stack id          FBbt
# 0     44                       LH_L  lateral horn        55  lateral horn
#    index JFRCtempate2010.mask130819          Name  Stack id          FBbt
# 0     44                       LH_L  lateral horn        55  lateral horn
# \caption{ LH\_L : lateral horn }
# 56
# label_tables/label_clean2_56_20190911.tex
#    index JFRCtempate2010.mask130819                    Name  Stack id  \
# 0     45                      LAL_L  lateral accessory lobe        56
#
#             FBbt
# 0  FBbt:00003681
#    index JFRCtempate2010.mask130819                    Name  Stack id  \
# 0     45                      LAL_L  lateral accessory lobe        56
#
#             FBbt
# 0  FBbt:00003681
# \caption{ LAL\_L : lateral accessory lobe }
# 28
# label_tables/label_clean2_28_20190911.tex
#    index JFRCtempate2010.mask130819                                 Name  \
# 0     25                      SIP_R  superior intermediate protocerebrum
#
#    Stack id           FBbt
# 0        28  FBbt:00045032
#    index JFRCtempate2010.mask130819                                 Name  \
# 0     25                      SIP_R  superior intermediate protocerebrum
#
#    Stack id           FBbt
# 0        28  FBbt:00045032
# \caption{ SIP\_R : superior intermediate protocerebrum }
# 7
# label_tables/label_clean2_7_20190911.tex
#    index JFRCtempate2010.mask130819          Name  Stack id          FBbt
# 0      5                       LH_R  lateral horn         7  lateral horn
#    index JFRCtempate2010.mask130819          Name  Stack id          FBbt
# 0      5                       LH_R  lateral horn         7  lateral horn
# \caption{ LH\_R : lateral horn }
# 14
# label_tables/label_clean2_14_20190911.tex
#    index JFRCtempate2010.mask130819             Name  Stack id           FBbt
# 0     12                       IB_R  inferior bridge        14  FBbt:00040050
#    index JFRCtempate2010.mask130819             Name  Stack id           FBbt
# 0     12                       IB_R  inferior bridge        14  FBbt:00040050
# \caption{ IB\_R : inferior bridge }
# 57
# label_tables/label_clean2_57_20190911.tex
#    index JFRCtempate2010.mask130819    Name  Stack id           FBbt
# 0     46                      CAN_L  cantle        57  FBbt:00045051
#    index JFRCtempate2010.mask130819    Name  Stack id           FBbt
# 0     46                      CAN_L  cantle        57  FBbt:00045051
# \caption{ CAN\_L : cantle }
# 58
# label_tables/label_clean2_58_20190911.tex
#    index JFRCtempate2010.mask130819                                      Name  \
# 0     47                     AMMC_L  antennal mechanosensory and motor center
#
#    Stack id           FBbt
# 0        58  FBbt:00003982
#    index JFRCtempate2010.mask130819                                      Name  \
# 0     47                     AMMC_L  antennal mechanosensory and motor center
#
#    Stack id           FBbt
# 0        58  FBbt:00003982
# \caption{ AMMC\_L : antennal mechanosensory and motor center }
# 29
# label_tables/label_clean2_29_20190911.tex
#    index JFRCtempate2010.mask130819                           Name  Stack id  \
# 0     26                      SMP_R  superior medial protocerebrum        29
#
#             FBbt
# 0  FBbt:00007055
#    index JFRCtempate2010.mask130819                           Name  Stack id  \
# 0     26                      SMP_R  superior medial protocerebrum        29
#
#             FBbt
# 0  FBbt:00007055
# \caption{ SMP\_R : superior medial protocerebrum }
# 59
# label_tables/label_clean2_59_20190911.tex
#    index JFRCtempate2010.mask130819            Name  Stack id           FBbt
# 0     48                      ICL_L  inferior clamp        59  FBbt:00040049
#    index JFRCtempate2010.mask130819            Name  Stack id           FBbt
# 0     48                      ICL_L  inferior clamp        59  FBbt:00040049
# \caption{ ICL\_L : inferior clamp }
# 30
# label_tables/label_clean2_30_20190911.tex
#    index JFRCtempate2010.mask130819                                  Name  \
# 0     27                     AVLP_R  anterior ventrolateral protocerebrum
#
#    Stack id           FBbt
# 0        30  FBbt:00040043
#    index JFRCtempate2010.mask130819                                  Name  \
# 0     27                     AVLP_R  anterior ventrolateral protocerebrum
#
#    Stack id           FBbt
# 0        30  FBbt:00040043
# \caption{ AVLP\_R : anterior ventrolateral protocerebrum }
# 60
# label_tables/label_clean2_60_20190911.tex
#    index JFRCtempate2010.mask130819  Name  Stack id           FBbt
# 0     49                      VES_L  vest        60  FBbt:00040041
#    index JFRCtempate2010.mask130819  Name  Stack id           FBbt
# 0     49                      VES_L  vest        60  FBbt:00040041
# \caption{ VES\_L : vest }
# 15
# label_tables/label_clean2_15_20190911.tex
#    index JFRCtempate2010.mask130819    Name  Stack id           FBbt
# 0     13                      ATL_R  antler        15  FBbt:00045039
#    index JFRCtempate2010.mask130819    Name  Stack id           FBbt
# 0     13                      ATL_R  antler        15  FBbt:00045039
# \caption{ ATL\_R : antler }
# 61
# label_tables/label_clean2_61_20190911.tex
#    index JFRCtempate2010.mask130819             Name  Stack id           FBbt
# 0     50                       IB_L  inferior bridge        61  FBbt:00040050
#    index JFRCtempate2010.mask130819             Name  Stack id           FBbt
# 0     50                       IB_L  inferior bridge        61  FBbt:00040050
# \caption{ IB\_L : inferior bridge }
# 31
# label_tables/label_clean2_31_20190911.tex
#    index JFRCtempate2010.mask130819                                   Name  \
# 0     28                     PVLP_R  posterior ventrolateral protocerebrum
#
#    Stack id           FBbt
# 0        31  FBbt:00040042
#    index JFRCtempate2010.mask130819                                   Name  \
# 0     28                     PVLP_R  posterior ventrolateral protocerebrum
#
#    Stack id           FBbt
# 0        31  FBbt:00040042
# \caption{ PVLP\_R : posterior ventrolateral protocerebrum }
# 62
# label_tables/label_clean2_62_20190911.tex
#    index JFRCtempate2010.mask130819    Name  Stack id           FBbt
# 0     51                      ATL_L  antler        62  FBbt:00045039
#    index JFRCtempate2010.mask130819    Name  Stack id           FBbt
# 0     51                      ATL_L  antler        62  FBbt:00045039
# \caption{ ATL\_L : antler }
# 63
# label_tables/label_clean2_63_20190911.tex
#    index JFRCtempate2010.mask130819     Name  Stack id           FBbt
# 0     52                      CRE_L  crepine        63  FBbt:00045037
#    index JFRCtempate2010.mask130819     Name  Stack id           FBbt
# 0     52                      CRE_L  crepine        63  FBbt:00045037
# \caption{ CRE\_L : crepine }

# %%
df_writeme.loc[['JRC2018','ANTs A']]
# Out:
#                     Mean  Std dev  10th perc  median  90th perc       N
# Template Algorithm
# JRC2018  ANTs A    4.659    3.824      1.000   3.606      9.513  140804
#          ANTs B    4.925    3.849      1.225   3.873      9.721  135624
#          ANTs C    5.311    4.045      1.414   4.301     10.464  141770
#          CMTK A    5.000    4.021      1.225   3.873     10.025  124912
#          CMTK C    4.834    3.885      1.225   3.808      9.667  128432
#          CMTK B    4.913    3.969      1.225   3.808      9.849  124664
#          Elastix B 5.796    4.684      1.414   4.528     12.062  119008
#          Elastix A 4.972    3.857      1.225   4.062      9.721  130008

# %%
# df_writeme.keys()
df_writeme.columns
# Out:
# Index(['Mean', 'Std dev', '10th perc', 'median', '90th perc', 'N'], dtype='object')

# %%
# df_writeme.loc[('JRC2018','ANTs A')]
# df_writeme.loc[pd.MultiIndex.from_tuples([('JRC2018','ANTs A'),('JRC2018','ANTs B')])]
# Out:
#                     Mean  Std dev  10th perc  median  90th perc       N
# JFRC2010 ANTs A    8.622    6.716      1.581   7.036     17.847  256308
#          ANTs B    4.956    3.951      1.225   3.808     10.075  146800
#          ANTs C    5.196    3.865      1.414   4.243     10.223  146628
#          CMTK A    8.446    8.462      1.581   5.788     17.958  118112
#          CMTK B    7.776    7.473      1.581   5.431     16.654  119994
#          CMTK C    7.686    7.710      1.732   5.523     15.133  137414
#          Elastix A 5.452    4.060      1.414   4.528     10.794  141868
#          Elastix B 7.431    5.954      1.581   5.745     15.764  122728
# JFRC2013 ANTs A    4.568    3.730      1.000   3.606      9.247  138368
#          ANTs B    6.720    4.943      1.581   5.523     13.675  128144
#          ANTs C    6.563    5.076      1.581   5.196     13.528  133550
#          CMTK A    5.413    4.345      1.225   4.183     11.180  130310
#          CMTK B    5.513    4.335      1.225   4.359     11.380  135338
#          CMTK C    6.112    4.696      1.414   5.000     12.490  141378
#          Elastix A 5.079    3.812      1.414   4.123      9.950  135046
#          Elastix B 5.653    4.511      1.414   4.472     11.533  132788
# JRC2018  ANTs A    4.659    3.824      1.000   3.606      9.513  140804
#          ANTs B    4.925    3.849      1.225   3.873      9.721  135624
#          ANTs C    5.311    4.045      1.414   4.301     10.464  141770
#          CMTK A    5.000    4.021      1.225   3.873     10.025  124912
#          CMTK B    4.913    3.969      1.225   3.808      9.849  124664
#          CMTK C    4.834    3.885      1.225   3.808      9.667  128432
#          Elastix A 4.972    3.857      1.225   4.062      9.721  130008
#          Elastix B 5.796    4.684      1.414   4.528     12.062  119008
# FCWB     ANTs A    5.500    4.759      1.000   4.000     12.124  128116
#          ANTs B    8.149    5.519      2.121   7.036     16.093  103628
#          ANTs C    7.903    5.370      2.000   6.819     15.330  113236
#          CMTK A    7.257    5.367      1.581   5.874     15.182  105712
#          CMTK B    6.848    5.312      1.581   5.339     14.916  109638
#          CMTK C    6.666    4.872      1.581   5.431     13.656  125260
#          Elastix A 8.217    5.590      2.000   7.106     16.340  122506
#          Elastix B 9.228    6.644      2.236   7.649     18.722  118268
# Tefor    ANTs A    4.641    3.842      1.000   3.606      9.539  141758
#          ANTs B    4.824    3.725      1.225   3.808      9.747  143886
#          ANTs C    5.033    3.597      1.414   4.183      9.849  165882
#          CMTK A    7.425    5.160      1.581   6.364     14.933  140012
#          CMTK B    6.941    4.928      1.581   5.874     13.946  136286
#          CMTK C    5.212    4.221      1.000   4.000     11.091  205034
#          Elastix A 5.800    4.444      1.414   4.583     12.104  126216
#          Elastix B 8.726    6.750      1.732   7.000     18.152  101056
